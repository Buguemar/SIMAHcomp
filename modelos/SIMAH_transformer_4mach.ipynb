# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import Counter
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import class_weight
sns.set_context(context="talk")
# %matplotlib inline

from keras import backend as K
import keras
import os, re, sys
import pandas as pd
from keras.utils import to_categorical
import ast
from sklearn.utils import class_weight
from keras.preprocessing import sequence
from keras.models import load_model
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,f1_score, confusion_matrix
from sklearn.preprocessing import normalize
import time
from keras.models import load_model
from keras import backend as K
import keras
'''
Compatible with tensorflow backend
gamma entre más alto más tolerante (queremos un gamma chico pero no demasiado! 0.25 - 5)
alpha pesos por clase (weights)
'''
def focal_loss(gamma=2., weights=1):   #weights np.asarray()
    weights= K.variable(weights)
    def focal_loss_fixed(y_true, y_pred):
        y_true = K.clip(y_true, K.epsilon(),1)
        y_pred = K.clip(y_pred,K.epsilon(),1)
        return - K.sum(weights* K.pow(1. - y_pred, gamma)* y_true * K.log(y_pred), axis=-1) 
    return focal_loss_fixed

keras.losses.focal_loss=keras.losses.MSE
keras.losses.focal_loss_fixed=keras.losses.MSE
# Out:
# Using TensorFlow backend.

# %%
#'baselines_4/cnn1_ce10_100.h5'
print ("Nh\t\t| IH\t\t| PH\t\t| SH\t\t| F-Macro")
print (0.92792793 ,'\t',0. ,'\t\t',        0.,'\t\t',         0.84057971,'\t',    0.4421269095182139)
#('baselines_4/cnn1_focal10_100.h5')
print (0.78674791,'\t', 0.13793103 ,'\t',0.09756098 ,'\t',0.56389987,'\t',   0.396534945974999  )
#('baselines_4/rnn_simple_100_focal15.h5')
print (0.9197861  ,'\t',0.10884354 ,'\t',0.0729927  ,'\t',0.78439425,'\t',  0.47150414622873116)
#('baselines_4/rnn1_100_focal15.h5')
print (0.92418033,'\t', 0.14876033 ,'\t',0.17073171 ,'\t',0.85254692,'\t',  0.5240548206636296)
#('baselines_4/rnn2_100_focal15.h5')
print (0.9054658 ,'\t', 0.13714286 ,'\t',0.10909091 ,'\t',0.74418605,'\t',  0.47397140213787825)
#('baselines_4/rnn3_100_focal15.h5')
print (0.78454333 ,'\t',0.10327022,'\t', 0.10362694 ,'\t',0.71553611,'\t', 0.42674414932927196)
#('baselines_4/cnn1_focal10_100_g3_100.h5')
print (0.91473851 ,'\t',0. ,'\t\t',        0.09386282 ,'\t',0.52150538,'\t',    0.38252667563241805)

#pasan a transformer: 1,2,7,8,9,10,12
# Out:
# Nh		| IH		| PH		| SH		| F-Macro
# 0.92792793 	 0.0 		 0.0 		 0.84057971 	 0.4421269095182139
# 0.78674791 	 0.13793103 	 0.09756098 	 0.56389987 	 0.396534945974999
# 0.9197861 	 0.10884354 	 0.0729927 	 0.78439425 	 0.47150414622873116
# 0.92418033 	 0.14876033 	 0.17073171 	 0.85254692 	 0.5240548206636296
# 0.9054658 	 0.13714286 	 0.10909091 	 0.74418605 	 0.47397140213787825
# 0.78454333 	 0.10327022 	 0.10362694 	 0.71553611 	 0.42674414932927196
# 0.91473851 	 0.0 		 0.09386282 	 0.52150538 	 0.38252667563241805

# %%
cnn_100_c = load_model('baselines_4/cnn1_ce10_100.h5')
#cnn_100_f = load_model('baselines_4/cnn1_focal10_100.h5')
gru_s = load_model('baselines_4/rnn_simple_100_focal15.h5')
gru1 = load_model('baselines_4/rnn1_100_focal15.h5')
gru2 = load_model('baselines_4/rnn2_100_focal15.h5')
#gru3 = load_model('baselines_4/rnn3_100_focal15.h5')
#cnn_100_f3 = load_model('baselines_4/cnn1_focal10_100_g3_100.h5')


list_models=['cnn_100_c', 'gru_s', 'gru1', 'gru2']
index_models=np.arange(4)
dict_models=dict((key, value) for (key, value) in zip(index_models,list_models))
modelos=[cnn_100_c, gru_s, gru1, gru2]
ind=np.arange(4)
dict_trainingModel=dict((key, value) for (key, value) in zip(ind,modelos))

# %%
predicciones_all=[]
X_train=np.load("matrices/X_train_4.npy")
X_train_rnn=np.load("matrices/X_train_rnn_4.npy")

bs=32
for i in dict_trainingModel.keys(): 
    print ("Agregando predicciones del modelo", dict_models[i])
    a_evaluar=dict_models[i]
    if a_evaluar[:3]!='gru':
        predicciones_all.append(dict_trainingModel[i].predict(X_train, batch_size=bs))
    else:
        predicciones_all.append(dict_trainingModel[i].predict(X_train_rnn, batch_size=bs))
        
predicciones_all_val=[]
X_val=np.load("matrices/X_val_ig_4.npy")
X_val_rnn=np.load("matrices/X_val_rnn_ig_4.npy")

bs=32
for i in dict_trainingModel.keys(): 
    print ("Agregando predicciones val del modelo", dict_models[i])
    a_evaluar=dict_models[i]
    if a_evaluar[:3]!='gru':
        predicciones_all_val.append(dict_trainingModel[i].predict(X_val, batch_size=bs))
    else:
        predicciones_all_val.append(dict_trainingModel[i].predict(X_val_rnn, batch_size=bs))
# Out:
# Agregando predicciones del modelo cnn_100_c
# Agregando predicciones del modelo gru_s
# Agregando predicciones del modelo gru1
# Agregando predicciones del modelo gru2
# Agregando predicciones val del modelo cnn_100_c
# Agregando predicciones val del modelo gru_s
# Agregando predicciones val del modelo gru1
# Agregando predicciones val del modelo gru2

# %%
predicciones_all_test=[]
X_test=np.load("matrices/X_test_ig_4.npy")
X_test_rnn=np.load("matrices/X_test_rnn_4.npy")

bs=32
for i in dict_trainingModel.keys(): 
    print ("Agregando predicciones test del modelo", dict_models[i])
    a_evaluar=dict_models[i]
    if a_evaluar[:3]!='gru':
        predicciones_all_test.append(dict_trainingModel[i].predict(X_test, batch_size=bs))
    else:
        predicciones_all_test.append(dict_trainingModel[i].predict(X_test_rnn, batch_size=bs))
# Out:
# Agregando predicciones test del modelo cnn_100_c
# Agregando predicciones test del modelo gru_s
# Agregando predicciones test del modelo gru1
# Agregando predicciones test del modelo gru2

# %%
matrix=np.asarray(predicciones_all)
print (matrix.shape)
matrix_val=np.asarray(predicciones_all_val)
print (matrix_val.shape)
matrix_test=np.asarray(predicciones_all_test)
print (matrix_test.shape)
# Out:
# (4, 6374, 4)
# (4, 2125, 4)
# (4, 2123, 4)

# %%
new_matrix=np.concatenate([matrix,matrix_val,matrix_test], axis=1)
new_matrix.shape
# Out:
# (4, 10622, 4)

# %%
class Dummy_Embeddings(nn.Module):
    def __init__(self, d_model, dummy_vectors): 
        super(Dummy_Embeddings, self).__init__()
        aux = torch.from_numpy(dummy_vectors)#, dtype='float32'))
        self.index2dummy = nn.Embedding(aux.size()[0], d_model)
        self.index2dummy.weigth=nn.Parameter(aux)
        self.index2dummy.weigth.requires_grad=False
        self.d_model = d_model
        
    def forward(self, x):
        aux=x.numpy()
        #print ("aux_size en dummy emb", aux.shape, aux)
        new_x= aux - np.ones(aux.shape)#cambiar aqui! (ver hojita de cuaderno)
        new_x= torch.from_numpy(new_x)
        #print ("nuevo aux con el menos 1s (clase 1 en ind 0 y los ids desde 5 ind)", aux)
        return self.index2dummy(new_x.long()) * math.sqrt(self.d_model) #debiese retornar matriz de batch_size x [ind_tw, k1,k2,k3,k4,k5,k6] (si son 6 modelos)
    
def match(objetos,ejemplo):
    i=0
    for obj in objetos:
        if obj==ejemplo:
            return i
        i+=1
        
class EncoderDecoderLogSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderLogSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.log_softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])


class EncoderDecoderSoft(nn.Module):
    def __init__(self, encoder, src_embed, sequential):
        super(EncoderDecoderSoft, self).__init__()
        self.encoder = encoder
        self.linearSoft = sequential
        self.src_embed = src_embed
        
    def forward(self, src, src_mask):
        out=self.encode(src, src_mask)
        retorno=self.toSoftmax(out)
        return retorno
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def toSoftmax(self, tensor):
        a=tensor.size()[0]
        b=tensor.size()[-1]
        c=tensor.size()[-2]
        new_tensor= np.zeros((a, b))
        ini=True
        for ai in range(a):
            for ci in range(c):
                if ini:
                    new_tensor[ai]=tensor.data[ai][ci].numpy()
                    ini=False
                else: 
                    new_tensor[ai]*=tensor.data[ai][ci].numpy()
            ini=True
            
        new_tensor=torch.from_numpy(new_tensor)
        lineal=self.linearSoft(new_tensor.float())
        return F.softmax(lineal, dim = -1)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
def clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

class EncoderDecoder(nn.Module):
    def __init__(self, encoder, src_embed, generator):
        super(EncoderDecoder, self).__init__()
        self.encoder = encoder
        self.src_embed = src_embed
        self.generator = generator
        
    def forward(self, src, src_mask):
        return  self.encode(src, src_mask)

    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
    
class Encoder(nn.Module):
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)
    
class LayerNorm(nn.Module):
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2
    
class SublayerConnection(nn.Module):
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        return x + self.dropout(sublayer(self.norm(x)))    
    
class EncoderLayer(nn.Module):
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)
    
def subsequent_mask(size):
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

class Generator(nn.Module):
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)
    
def attention(query, key, value, mask=None, dropout=None):
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) \
             / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    p_attn = F.softmax(scores, dim = -1)
    if dropout is not None:
        p_attn = dropout(p_attn)
    return torch.matmul(p_attn, value), p_attn

class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        assert d_model % h == 0
        self.d_k = d_model // h
        self.h = h
        self.linears = clones(nn.Linear(d_model, d_model), 4)
        self.attn = None
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, query, key, value, mask=None):
        if mask is not None:
            mask = mask.unsqueeze(1)
        nbatches = query.size(0)
        
        query, key, value = \
            [l(x).view(nbatches, -1, self.h, self.d_k).transpose(1, 2)
             for l, x in zip(self.linears, (query, key, value))]
         
        x, self.attn = attention(query, key, value, mask=mask, 
                                 dropout=self.dropout)
        
        x = x.transpose(1, 2).contiguous() \
             .view(nbatches, -1, self.h * self.d_k)
        return self.linears[-1](x)
    
class PositionalText(nn.Module):
    def __init__(self, d_model, dropout, max_len=5):
        super(PositionalText, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        x_text=x.data[:,0][:,None,:]
        x_machines=x.data[:,1:]
        
        x_return = x_machines* x_text
        return self.dropout(x_return)
    
class PositionalText_concat(nn.Module):
    def __init__(self, d_model, dropout, max_len=5):
        super(PositionalText_concat, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        return self.dropout(x)

# %%
def data_gen(batch_size,mode,n_machines,new_matrix):  
    """ESTA FUNCION DEBERÁ RETORNAR MATRICES DE TAMAÑO BATCH_SIZE * TW,M1,M2,M3,M4,M5,M6
    CADA EJEMPLO DEBERÁ SER ESTILO [ID_T, 1,2,1,2,1,2] SIENDO 1 CUANDO LA CLASE PREDICHA ES LA 0
    2 PARA CLASE PREDICHA 1, ETC. ID_T DEBEŔA INICIAR EN 5 PARA REFERIRSE AL PRIMER TW (EL PRIMERO DE TRAIN)"""
    x_data=[] 
    y_data=[]
    if mode=='Train':
        max_objs=matrix.shape[1]
        x_list=np.arange(max_objs)
        np.random.shuffle(x_list)
        objs=df_train['Unnamed: 0'].values
        objs=[obj+5 for obj in objs]
        labels=np.load("../../forSIMAH/y_train_num_4.npy")
        labels=labels+ np.ones(labels.shape)       
    if mode=='Val':
        max_objs=matrix_val.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1] for x in x_list]
        np.random.shuffle(x_list)
        objs=df_val['Unnamed: 0'].values        
        objs=[obj+5 for obj in objs]
        labels=np.load("../../forSIMAH/y_val_num_4.npy")
        labels=labels+ np.ones(labels.shape) 
    if mode=='Test':
        max_objs=matrix_test.shape[1] 
        x_list=np.arange(max_objs)
        x_list=[x+matrix.shape[1]+matrix_val.shape[1] for x in x_list]
        #np.random.shuffle(x_list)
        #print ("X LIST SIN SHUFFLE", x_list)
        total=matrix.shape[1]+matrix_val.shape[1]
        objs=np.arange(total, total+max_objs)
        objs=[obj+5 for obj in objs]
        
    if len(x_list)%batch_size==0:
        n_batches=len(x_list)/batch_size
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
    else:
        n_batches=int(len(x_list)/batch_size)
        resto=int(len(x_list)-n_batches*batch_size)
        to_repeat=batch_size-resto        
        for nb in range(n_batches): 
            x_data.append(x_list[nb*batch_size:(nb+1)*batch_size])
        cola=list(x_list[(nb+1)*batch_size:])
        for i in range(to_repeat):
            indice= np.random.randint(len(x_list))
            cola.append(x_list[indice])
        x_data.append(np.asarray(cola))
        if mode=='Test':
            print ("SE TUVIERON QUE REPETIR", to_repeat, "EJEMPLOS")
    
    new_x_data=[] 
    for batch in x_data:
        temp=[]
        for exam in batch:
            if mode=='Train':
                temp2=[objs[exam]] ### obj evaluado en maquinas
            elif mode=='Val':
                temp2=[objs[exam-matrix.shape[1]]] 
            else:
                temp2=[objs[exam-matrix.shape[1]-matrix_val.shape[1]]]                
            for m in range(n_machines): 
                temp2= temp2 + [np.argmax(new_matrix[m][exam])+1] 
            temp.append(temp2)
        new_x_data.append(temp)   

    if mode=='Train' or mode=='Val':    
        y_data=[]
        for batch in new_x_data:
            temp_y=[]
            for exam in batch:
                q=exam[0]
                indice=match(objs, q)    
                temp_y.append([labels[indice]])       
            y_data.append(temp_y)
        y_data=np.asarray(y_data)
        
    new_x_data=np.asarray(new_x_data)
    
    if mode=='Train' or mode=='Val':
        for x,y in zip(new_x_data, y_data):
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            har = Variable(torch.from_numpy(np.asarray(y)), requires_grad=False)
            yield Batch(src, har, 0)
    else:
        for x in new_x_data:
            src = Variable(torch.from_numpy(np.asarray(x)), requires_grad=False)
            yield Batch(src, None, 0)

# %%
df_train=pd.read_csv("../Train_data_compeition.csv")
df_val=pd.read_csv("../Validation_data_competition.csv")
df_test=pd.read_csv("../testset-competition.csv")
df_train.head()
# Out:
#    Unnamed: 0                                      tweet_content  harassment  \
# 0           0  pics mexican school girl naked melanie safka f...           1
# 1           1  RT shereiqns Having curly hair is a gotdamn ch...           0
# 2           2   BreakingNews 7 Unexplained Prisoners Deaths M...           0
# 3           3   girl dirty quarterback latino pokemon young h...           1
# 4           4   miliondollameat sexting n ngirl daddy n nme l...           1
#
#    IndirectH  PhysicalH  SexualH
# 0          0          0        1
# 1          0          0        0
# 2          0          0        0
# 3          0          0        1
# 4          0          0        1

# %%
Ks=np.load("../Orthogonals_768.npy")
print (Ks.shape)
random=np.random.randint(Ks.shape[0], size=4)
K_list=[Ks[k] for k in random]
print (np.asarray(K_list).shape)
len(K_list)
# Out:
# (768, 768)
# (4, 768)
# 4

# %% [markdown]
# # por qué parte en 5?

# %%
K_list_ext=K_list
objs_train=df_train['Unnamed: 0'].values
objs_val=df_val['Unnamed: 0'].values
objs_test=np.arange(df_test.shape[0])
tope=len(objs_train)+len(objs_val)
objs_test=[elem+tope for elem in objs_test]
print (objs_train.shape)
print (objs_val.shape)
print (len(objs_test))
#print (objs_test.shape)
llaves=np.concatenate([objs_train,objs_val,objs_test])
#valores=np.arange(5, len(objs_train)+len(objs_val)+len(objs_test)+5)
len(llaves)
# Out:
# (6374,)
# (2125,)
# 2123
# 10622

# %%
#dict_IDObj=dict((key, value) for (key, value) in zip(llaves,valores))
#dict_ObjID=dict((key, value) for (key, value) in zip(valores,llaves))
#len(dict_ObjID)

# %%
contador=0
for i in range(tope):
    vector=np.load("../../vectors/"+str(i)+".npy")
    K_list_ext.append(vector[0])
for i in range(len(objs_test)):
    vector=np.load("../../test_vectors/"+str(i)+".npy")
    K_list_ext.append(vector[0])
print ("largo de lista de vectores bert (considerando dummy clases)", len(K_list_ext))
# Out:
# largo de lista de vectores bert (considerando dummy clases) 10626

# %%
len(K_list_ext)
# Out:
# 10626

# %%
K_list_new= np.asarray(K_list_ext, dtype='float32')
K_list_new.shape
# Out:
# (10626, 768)

# %%
def make_model_concat(target, N=2, d_model=768, d_ff=1024, h=4, dropout=0.3, soft=True):  #recibir src_vocab si lo utiliza dummy_Emb
    c = copy.deepcopy
    attn = MultiHeadedAttention(h, d_model)
    ff = PositionwiseFeedForward(d_model, d_ff, dropout)
    position = PositionalText_concat(d_model, dropout)
    if soft:
        print ("Creando modelo con salida Softmax")
        model = EncoderDecoderSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(768, K_list_new), c(position)),
            nn.Linear(d_model, 4))
    else:
        print ("")
        print ("Creando modelo con salida Log_softmax")
        model = EncoderDecoderLogSoft(
            Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N),
            nn.Sequential(Dummy_Embeddings(768, K_list_new), c(position)),
            nn.Linear(d_model, 4))

    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform(p)
    return model

class Batch:
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :]
            self.trg_y = trg[:, 0:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
            
    @staticmethod
    def make_std_mask(tgt, pad):
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
def run_epoch(data_iter, model, loss_compute, mode):
    if mode=='Test':
        with torch.no_grad():
            start = time.time()
            total_datos = 0
            total_loss = 0
            total_acc=0
            total_fm1=0
            total_fs=0
            n_batches = 0
            cm_last=np.zeros((4,4))
            pred_classes=[]
            for i, batch in enumerate(data_iter):
                out = model.forward(batch.src, batch.src_mask)
                pred_classes.append(out.argmax(dim=-1).numpy())
                #la loss del batch es sobre todos los ejemplos o es promedio en batch?
                
            return pred_classes
    
    else:
        start = time.time()
        total_learners = 0
        total_datos = 0
        total_loss = 0
        total_acc=0
        total_fm1=0
        total_fs=0
        n_batches = 0
        cm_last=np.zeros((4,4))
        for i, batch in enumerate(data_iter):
            out = model.forward(batch.src, batch.src_mask)
            loss,acc,f1,cm = loss_compute(out, batch.trg_y, batch.ntokens, mode)
            cm_last+=cm
            f_ma=np.mean(f1)
            total_loss += loss
            total_acc += np.array(acc)
            total_fm1 += np.sum(f1)/4.0
            total_fs += f1  
            total_datos += batch.ntokens
            n_batches += 1
        return total_loss/n_batches, torch.from_numpy(np.array(total_acc))/n_batches, torch.from_numpy(np.array(total_fm1))/n_batches, torch.from_numpy(np.array(total_fs))/n_batches, cm_last

# %%
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of learners + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    maximo=max(src_elements, tgt_elements)
    return maximo

class NoamOpt:
    "Optim wrapper that implements rate."
    def __init__(self, model_size, factor, warmup, optimizer):
        self.optimizer = optimizer
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0
        
    def step(self):
        "Update parameters and rate"
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        #print ("Rate de Noam_opt", self._rate, self._step)
        self.optimizer.step()
        
    def rate(self, step = None):
        "Implement `lrate` above"
        if step is None:
            step = self._step
        return self.factor * \
            (self.model_size ** (-0.5) *
            min(step ** (-0.5), step * self.warmup ** (-1.5)))
        
def get_std_opt(model):
    return NoamOpt(model.src_embed[0].d_model, 2, 4000,
            torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))

class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(size_average=False)
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        mask = torch.nonzero(target.data == self.padding_idx)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))
    
class LabelCCE(nn.Module):
    def __init__(self, class_weights):
        super(LabelCCE, self).__init__()
        self.criterion = nn.CrossEntropyLoss(weight=class_weights)
                       
    def forward(self, x, target):
        return self.criterion(x, target)
    
class FocalLoss(nn.Module):
    def __init__(self, weights, gamma=2.0, reduce=True):#, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.weights = weights
        self.gamma = gamma
        #self.logits = logits
        self.reduce = reduce

    def forward(self, x, y):
        tensors = []
        for l in y:
            tensors.append(torch.zeros(4).scatter_(0, torch.tensor(l), 1))
        result = torch.stack(tensors, 0)
        
        CCE_loss = F.cross_entropy(x, result.long().argmax(dim=-1), reduction='none', weight=self.weights.float())
        pt = torch.exp(-CCE_loss)
        factor= (1-pt)**self.gamma * CCE_loss
        
        F_loss = factor  #*self.weights.float()-- peso esta dentro de la funcion

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss
        
class SimpleLossComputeFL:
    "A simple loss compute and train function."
    def __init__(self, criterion, opt=None):
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm, mode):        
        y_new=(y.float()-torch.ones((y.shape[0],y.shape[1]))).int()
        ac=accuracy_scorer(x, y_new)
        f1=f_scorer(x, y_new)
        cm=compute_confusion_matrix(x, y_new)
        tempa= x.contiguous().view(-1, x.size(-1))
        tempb= y_new.long().contiguous().view(-1)
        loss = self.criterion(tempa, tempb) #/ norm
        if mode!='Test':
            loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.optimizer.zero_grad()
        return [loss.data, ac ,f1, cm] #*norm #[0] * norm
    
class PositionwiseFeedForward(nn.Module):
    "Implements FFN equation."
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))

# %% [markdown]
# # DESDE ACA

# %%
def accuracy_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return accuracy_score(target.numpy(),predicho.numpy())

def f_scorer(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return f1_score(target.numpy(),predicho.numpy(), average=None, labels=[0,1,2,3])

def compute_confusion_matrix(predicho, target):
    predicho= torch.argmax(predicho, dim=1)
    return confusion_matrix(target.numpy(), predicho.numpy(), labels=[0,1,2,3])

y_train_har=np.load("matrices/y_train_num_4.npy")
print (y_train_har[:10])
class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train_har), y_train_har)
print (class_weights)

if not sys.warnoptions:
    warnings.simplefilter("ignore")
# Out:
# [3 0 0 3 3 0 3 3 0 0]
# [ 0.43526359 28.97272727 20.96710526  0.61715724]

# %% [markdown]
# ## Modelos

# %%
### Mejor caso a superar: 
print ("Nh\t\t| IH\t\t| PH\t\t| SH\t\t| F-Macro")
#('baselines_4/rnn1_100_focal15.h5')
print (0.92418033,'\t', 0.14876033 ,'\t',0.17073171 ,'\t',0.85254692,'\t',  0.5240548206636296)
#('baselines_4/rnn2_100_focal15.h5')
print (0.9054658 ,'\t', 0.13714286 ,'\t',0.10909091 ,'\t',0.74418605,'\t',  0.47397140213787825)
# Out:
# Nh		| IH		| PH		| SH		| F-Macro
# 0.92418033 	 0.14876033 	 0.17073171 	 0.85254692 	 0.5240548206636296
# 0.9054658 	 0.13714286 	 0.10909091 	 0.74418605 	 0.47397140213787825

# %%
V = 4
pesos = torch.from_numpy(class_weights).float()
print (pesos)
criterion = FocalLoss(weights=pesos)
model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.3)
model_opt = NoamOpt(model.src_embed[0].d_model, 1, 500, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

hist_train_loss=[]
hist_train_acc=[]
hist_train_fma=[]
hist_val_loss=[]
hist_val_acc=[]
hist_val_fma=[]

for epoch in range(30):
    print ("")
    print (model_opt._rate)
    print ("")
    model.train()
    DATA=data_gen(35, 'Train', 4, new_matrix)
    loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
    hist_train_loss.append(loss_train)
    hist_train_acc.append(acc_train)
    hist_train_fma.append(fma_train)

    model.eval()
    loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(35, 'Val', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
    print ("Validando Epoch",epoch)
    print ("loss_val:",loss_val)
    print ("Acc_val:",acc_val)
    print ("f_score_val:",fma_val)
    print ("f_score_val:",f_val_none)
    hist_val_loss.append(loss_val)
    hist_val_acc.append(acc_val)
    hist_val_fma.append(fma_val)
# Out:
# tensor([ 0.4353, 28.9727, 20.9671,  0.6172])
# Creando modelo con salida Softmax
#
# 0
#
# Validando Epoch 0
# loss_val: tensor(2.3257)
# Acc_val: tensor(0.8782, dtype=torch.float64)
# f_score_val: tensor(0.4462, dtype=torch.float64)
# f_score_val: tensor([0.9285, 0.0164, 0.0164, 0.8236], dtype=torch.float64)
#
# 0.0005906299602966311
#
# Validando Epoch 1
# loss_val: tensor(2.2796)
# Acc_val: tensor(0.8782, dtype=torch.float64)
# f_score_val: tensor(0.4633, dtype=torch.float64)
# f_score_val: tensor([0.9300, 0.0574, 0.0328, 0.8330], dtype=torch.float64)
#
# 0.0011812599205932623
#
# Validando Epoch 2
# loss_val: tensor(2.1611)
# Acc_val: tensor(0.8525, dtype=torch.float64)
# f_score_val: tensor(0.4760, dtype=torch.float64)
# f_score_val: tensor([0.9260, 0.0852, 0.0934, 0.7994], dtype=torch.float64)
#
# 0.0015400443144886933
#
# Validando Epoch 3
# loss_val: tensor(2.1672)
# Acc_val: tensor(0.8595, dtype=torch.float64)
# f_score_val: tensor(0.4750, dtype=torch.float64)
# f_score_val: tensor([0.9271, 0.0721, 0.0831, 0.8176], dtype=torch.float64)
#
# 0.0013337174993009997
#
# Validando Epoch 4
# loss_val: tensor(2.1733)
# Acc_val: tensor(0.8623, dtype=torch.float64)
# f_score_val: tensor(0.4790, dtype=torch.float64)
# f_score_val: tensor([0.9281, 0.1104, 0.0607, 0.8169], dtype=torch.float64)
#
# 0.0011929131964872255
#
# Validando Epoch 5
# loss_val: tensor(2.1748)
# Acc_val: tensor(0.8651, dtype=torch.float64)
# f_score_val: tensor(0.4814, dtype=torch.float64)
# f_score_val: tensor([0.9278, 0.0858, 0.0913, 0.8206], dtype=torch.float64)
#
# 0.001088975778102743
#
# Validando Epoch 6
# loss_val: tensor(2.1323)
# Acc_val: tensor(0.8637, dtype=torch.float64)
# f_score_val: tensor(0.4827, dtype=torch.float64)
# f_score_val: tensor([0.9275, 0.0923, 0.0861, 0.8249], dtype=torch.float64)
#
# 0.0010081956635329735
#
# Validando Epoch 7
# loss_val: tensor(2.1297)
# Acc_val: tensor(0.8721, dtype=torch.float64)
# f_score_val: tensor(0.4992, dtype=torch.float64)
# f_score_val: tensor([0.9312, 0.1131, 0.1202, 0.8324], dtype=torch.float64)
#
# 0.0009430806879429013
#
# Validando Epoch 8
# loss_val: tensor(2.1756)
# Acc_val: tensor(0.8721, dtype=torch.float64)
# f_score_val: tensor(0.4812, dtype=torch.float64)
# f_score_val: tensor([0.9293, 0.0962, 0.0639, 0.8356], dtype=torch.float64)
#
# 0.0008891449995339999
#
# Validando Epoch 9
# loss_val: tensor(2.1480)
# Acc_val: tensor(0.8740, dtype=torch.float64)
# f_score_val: tensor(0.4823, dtype=torch.float64)
# f_score_val: tensor([0.9297, 0.0907, 0.0732, 0.8358], dtype=torch.float64)
#
# 0.0008435170106030374
#
# Validando Epoch 10
# loss_val: tensor(2.1632)
# Acc_val: tensor(0.8703, dtype=torch.float64)
# f_score_val: tensor(0.4860, dtype=torch.float64)
# f_score_val: tensor([0.9284, 0.0940, 0.0896, 0.8318], dtype=torch.float64)
#
# 0.0008042619130022738
#
# Validando Epoch 11
# loss_val: tensor(2.1318)
# Acc_val: tensor(0.8642, dtype=torch.float64)
# f_score_val: tensor(0.4831, dtype=torch.float64)
# f_score_val: tensor([0.9271, 0.1047, 0.0794, 0.8213], dtype=torch.float64)
#
# 0.0007700221572443466
#
# Validando Epoch 12
# loss_val: tensor(2.1305)
# Acc_val: tensor(0.8689, dtype=torch.float64)
# f_score_val: tensor(0.4870, dtype=torch.float64)
# f_score_val: tensor([0.9292, 0.0880, 0.1022, 0.8288], dtype=torch.float64)
#
# 0.0007398133585712865
#
# Validando Epoch 13
# loss_val: tensor(2.1344)
# Acc_val: tensor(0.8707, dtype=torch.float64)
# f_score_val: tensor(0.4894, dtype=torch.float64)
# f_score_val: tensor([0.9306, 0.1049, 0.0956, 0.8267], dtype=torch.float64)
#
# 0.0007129019904470364
#
# Validando Epoch 14
# loss_val: tensor(2.1480)
# Acc_val: tensor(0.8698, dtype=torch.float64)
# f_score_val: tensor(0.4958, dtype=torch.float64)
# f_score_val: tensor([0.9287, 0.1131, 0.1066, 0.8350], dtype=torch.float64)
#
# 0.0006887287551117565
#
# Validando Epoch 15
# loss_val: tensor(2.1376)
# Acc_val: tensor(0.8698, dtype=torch.float64)
# f_score_val: tensor(0.4908, dtype=torch.float64)
# f_score_val: tensor([0.9308, 0.1022, 0.1005, 0.8299], dtype=torch.float64)
#
# 0.0006668587496504999
#
# Validando Epoch 16
# loss_val: tensor(2.1301)
# Acc_val: tensor(0.8670, dtype=torch.float64)
# f_score_val: tensor(0.4858, dtype=torch.float64)
# f_score_val: tensor([0.9276, 0.1005, 0.0878, 0.8275], dtype=torch.float64)
#
# 0.0006469480146297259
#
# Validando Epoch 17
# loss_val: tensor(2.1543)
# Acc_val: tensor(0.8684, dtype=torch.float64)
# f_score_val: tensor(0.4857, dtype=torch.float64)
# f_score_val: tensor([0.9286, 0.0923, 0.0945, 0.8274], dtype=torch.float64)
#
# 0.0006287204586286008
#
# Validando Epoch 18
# loss_val: tensor(2.1307)
# Acc_val: tensor(0.8674, dtype=torch.float64)
# f_score_val: tensor(0.4775, dtype=torch.float64)
# f_score_val: tensor([0.9281, 0.0634, 0.0934, 0.8252], dtype=torch.float64)
#
# 0.0006119515577562986
#
# Validando Epoch 19
# loss_val: tensor(2.1443)
# Acc_val: tensor(0.8707, dtype=torch.float64)
# f_score_val: tensor(0.4807, dtype=torch.float64)
# f_score_val: tensor([0.9306, 0.0874, 0.0803, 0.8246], dtype=torch.float64)
#
# 0.0005964565982436127
#
# Validando Epoch 20
# loss_val: tensor(2.1289)
# Acc_val: tensor(0.8735, dtype=torch.float64)
# f_score_val: tensor(0.4856, dtype=torch.float64)
# f_score_val: tensor([0.9309, 0.0896, 0.0902, 0.8318], dtype=torch.float64)
#
# 0.0005820820377365756
#
# Validando Epoch 21
# loss_val: tensor(2.1292)
# Acc_val: tensor(0.8726, dtype=torch.float64)
# f_score_val: tensor(0.4949, dtype=torch.float64)
# f_score_val: tensor([0.9285, 0.1120, 0.0984, 0.8407], dtype=torch.float64)
#
# 0.000568699052533973
#
# Validando Epoch 22
# loss_val: tensor(2.1294)
# Acc_val: tensor(0.8731, dtype=torch.float64)
# f_score_val: tensor(0.4889, dtype=torch.float64)
# f_score_val: tensor([0.9309, 0.0964, 0.0967, 0.8314], dtype=torch.float64)
#
# 0.00055619864576883
#
# Validando Epoch 23
# loss_val: tensor(2.1941)
# Acc_val: tensor(0.8693, dtype=torch.float64)
# f_score_val: tensor(0.4845, dtype=torch.float64)
# f_score_val: tensor([0.9283, 0.0869, 0.0913, 0.8314], dtype=torch.float64)
#
# 0.0005444878890513716
#
# Validando Epoch 24
# loss_val: tensor(2.1321)
# Acc_val: tensor(0.8740, dtype=torch.float64)
# f_score_val: tensor(0.4875, dtype=torch.float64)
# f_score_val: tensor([0.9306, 0.0852, 0.1011, 0.8332], dtype=torch.float64)
#
# 0.0005334869997203999
#
# Validando Epoch 25
# loss_val: tensor(2.1456)
# Acc_val: tensor(0.8735, dtype=torch.float64)
# f_score_val: tensor(0.4846, dtype=torch.float64)
# f_score_val: tensor([0.9310, 0.0907, 0.0776, 0.8389], dtype=torch.float64)
#
# 0.0005231270426581515
#
# Validando Epoch 26
# loss_val: tensor(2.1527)
# Acc_val: tensor(0.8735, dtype=torch.float64)
# f_score_val: tensor(0.4920, dtype=torch.float64)
# f_score_val: tensor([0.9306, 0.1158, 0.0891, 0.8327], dtype=torch.float64)
#
# 0.0005133481048295645
#
# Validando Epoch 27
# loss_val: tensor(2.1288)
# Acc_val: tensor(0.8745, dtype=torch.float64)
# f_score_val: tensor(0.4891, dtype=torch.float64)
# f_score_val: tensor([0.9316, 0.1022, 0.0869, 0.8358], dtype=torch.float64)
#
# 0.0005040978317664867
#
# Validando Epoch 28
# loss_val: tensor(2.1287)
# Acc_val: tensor(0.8749, dtype=torch.float64)
# f_score_val: tensor(0.4951, dtype=torch.float64)
# f_score_val: tensor([0.9320, 0.1060, 0.1069, 0.8355], dtype=torch.float64)
#
# 0.0004953302441307022
#
# Validando Epoch 29
# loss_val: tensor(2.1293)
# Acc_val: tensor(0.8726, dtype=torch.float64)
# f_score_val: tensor(0.4960, dtype=torch.float64)
# f_score_val: tensor([0.9297, 0.1213, 0.0956, 0.8375], dtype=torch.float64)

# %%
plt.plot(hist_train_loss, label='loss train')
plt.plot(hist_val_loss,label='loss val')
plt.legend(loc='upper left')
plt.title("Loss vs epoch")
plt.show()

plt.plot(hist_train_acc, label='Acc train')
plt.plot(hist_val_acc, label='Acc val')
plt.legend(loc='upper left')
plt.title("Accuracy vs epoch")
plt.show()

plt.plot(hist_train_fma, label='f_ma train')
plt.plot(hist_val_fma, label='f_ma val')
plt.legend(loc='upper left')
plt.title("F-score macro vs epoch")
plt.show()

# %% [markdown]
# ### Testing model

# %%
model.eval()
print ("Testing")
predicciones = run_epoch(data_gen(35, 'Test', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
predicciones=np.concatenate(predicciones, axis=-1)
print (predicciones.shape)
print (Counter(predicciones))
sns.countplot(predicciones)
# Out:
# Testing
# SE TUVIERON QUE REPETIR 12 EJEMPLOS
# (2135,)
# Counter({0: 1651, 3: 333, 1: 79, 2: 72})

# %%
model.eval()
print ("Validando")
loss_val, acc_val,fma_val, f_val_none, cm_val = run_epoch(data_gen(35, 'Val', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
print ("Validando Epoch",epoch)
print ("loss_val:",loss_val)
print ("Acc_val:",acc_val)
print ("f_score_val:",fma_val)
print ("f_score_val:",f_val_none)
# Out:
# Validando
# Validando Epoch 29
# loss_val: tensor(2.1290)
# Acc_val: tensor(0.8735, dtype=torch.float64)
# f_score_val: tensor(0.4833, dtype=torch.float64)
# f_score_val: tensor([0.9304, 0.0923, 0.0831, 0.8273], dtype=torch.float64)

# %%
print (Counter(y_train_har))
sns.countplot(y_train_har)
# Out:
# Counter({0: 3661, 3: 2582, 2: 76, 1: 55})

# %%
y_val_har=np.load("matrices/y_val_num_4.npy")
print (Counter(y_val_har))
sns.countplot(y_val_har)
# Out:
# Counter({0: 1493, 3: 525, 1: 71, 2: 36})

# %% [markdown]
# # Otros settings

# %%
#probar factor 5000 con 50 epochs y 0.4 dropout

# %%
V = 4
pesos = torch.from_numpy(class_weights).float()
print (pesos)
criterion = FocalLoss(weights=pesos)
model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.4)
model_opt = NoamOpt(model.src_embed[0].d_model, 1, 5000, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

hist_train_loss=[]
hist_train_acc=[]
hist_train_fma=[]
hist_val_loss=[]
hist_val_acc=[]
hist_val_fma=[]

for epoch in range(50):
    print ("")
    print (model_opt._rate)
    print ("")
    model.train()
    DATA=data_gen(35, 'Train', 4, new_matrix)
    loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
    hist_train_loss.append(loss_train)
    hist_train_acc.append(acc_train)
    hist_train_fma.append(fma_train)

    model.eval()
    loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(35, 'Val', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
    print ("Validando Epoch",epoch)
    print ("loss_val:",loss_val)
    print ("Acc_val:",acc_val)
    print ("f_score_val:",fma_val)
    print ("f_score_val:",f_val_none)
    hist_val_loss.append(loss_val)
    hist_val_acc.append(acc_val)
    hist_val_fma.append(fma_val)
# Out:
# tensor([ 0.4353, 28.9727, 20.9671,  0.6172])
# Creando modelo con salida Softmax
#
# 0
#
# Validando Epoch 0
# loss_val: tensor(2.2940)
# Acc_val: tensor(0.6721, dtype=torch.float64)
# f_score_val: tensor(0.3510, dtype=torch.float64)
# f_score_val: tensor([0.7875, 0.0555, 0.0066, 0.5545], dtype=torch.float64)
#
# 1.867735928872173e-05
#
# Validando Epoch 1
# loss_val: tensor(2.2846)
# Acc_val: tensor(0.6951, dtype=torch.float64)
# f_score_val: tensor(0.3650, dtype=torch.float64)
# f_score_val: tensor([0.8039, 0.0517, 0.0219, 0.5825], dtype=torch.float64)
#
# 3.735471857744346e-05
#
# Validando Epoch 2
# loss_val: tensor(2.2693)
# Acc_val: tensor(0.7415, dtype=torch.float64)
# f_score_val: tensor(0.3916, dtype=torch.float64)
# f_score_val: tensor([0.8349, 0.0656, 0.0120, 0.6540], dtype=torch.float64)
#
# 5.603207786616519e-05
#
# Validando Epoch 3
# loss_val: tensor(2.2719)
# Acc_val: tensor(0.7794, dtype=torch.float64)
# f_score_val: tensor(0.4131, dtype=torch.float64)
# f_score_val: tensor([0.8589, 0.0557, 0.0219, 0.7161], dtype=torch.float64)
#
# 7.470943715488692e-05
#
# Validando Epoch 4
# loss_val: tensor(2.2623)
# Acc_val: tensor(0.8136, dtype=torch.float64)
# f_score_val: tensor(0.4353, dtype=torch.float64)
# f_score_val: tensor([0.8819, 0.0656, 0.0205, 0.7734], dtype=torch.float64)
#
# 9.338679644360864e-05
#
# Validando Epoch 5
# loss_val: tensor(2.2555)
# Acc_val: tensor(0.8426, dtype=torch.float64)
# f_score_val: tensor(0.4464, dtype=torch.float64)
# f_score_val: tensor([0.9009, 0.0694, 0.0164, 0.7990], dtype=torch.float64)
#
# 0.00011206415573233038
#
# Validando Epoch 6
# loss_val: tensor(2.2367)
# Acc_val: tensor(0.8511, dtype=torch.float64)
# f_score_val: tensor(0.4510, dtype=torch.float64)
# f_score_val: tensor([0.9062, 0.0787, 0.0082, 0.8107], dtype=torch.float64)
#
# 0.00013074151502105212
#
# Validando Epoch 7
# loss_val: tensor(2.2560)
# Acc_val: tensor(0.8637, dtype=torch.float64)
# f_score_val: tensor(0.4534, dtype=torch.float64)
# f_score_val: tensor([0.9150, 0.0714, 0.0109, 0.8162], dtype=torch.float64)
#
# 0.00014941887430977384
#
# Validando Epoch 8
# loss_val: tensor(2.2264)
# Acc_val: tensor(0.8679, dtype=torch.float64)
# f_score_val: tensor(0.4612, dtype=torch.float64)
# f_score_val: tensor([0.9169, 0.0874, 0.0082, 0.8324], dtype=torch.float64)
#
# 0.0001680962335984956
#
# Validando Epoch 9
# loss_val: tensor(2.2621)
# Acc_val: tensor(0.8763, dtype=torch.float64)
# f_score_val: tensor(0.4648, dtype=torch.float64)
# f_score_val: tensor([0.9239, 0.0686, 0.0164, 0.8504], dtype=torch.float64)
#
# 0.0001867735928872173
#
# Validando Epoch 10
# loss_val: tensor(2.2167)
# Acc_val: tensor(0.8726, dtype=torch.float64)
# f_score_val: tensor(0.4618, dtype=torch.float64)
# f_score_val: tensor([0.9217, 0.0776, 0.0066, 0.8412], dtype=torch.float64)
#
# 0.00020545095217593904
#
# Validando Epoch 11
# loss_val: tensor(2.2036)
# Acc_val: tensor(0.8721, dtype=torch.float64)
# f_score_val: tensor(0.4665, dtype=torch.float64)
# f_score_val: tensor([0.9236, 0.0874, 0.0109, 0.8440], dtype=torch.float64)
#
# 0.00022412831146466076
#
# Validando Epoch 12
# loss_val: tensor(2.1871)
# Acc_val: tensor(0.8726, dtype=torch.float64)
# f_score_val: tensor(0.4765, dtype=torch.float64)
# f_score_val: tensor([0.9225, 0.1186, 0.0164, 0.8484], dtype=torch.float64)
#
# 0.00024280567075338251
#
# Validando Epoch 13
# loss_val: tensor(2.1868)
# Acc_val: tensor(0.8684, dtype=torch.float64)
# f_score_val: tensor(0.4696, dtype=torch.float64)
# f_score_val: tensor([0.9218, 0.0923, 0.0191, 0.8452], dtype=torch.float64)
#
# 0.00026148303004210424
#
# Validando Epoch 14
# loss_val: tensor(2.1816)
# Acc_val: tensor(0.8689, dtype=torch.float64)
# f_score_val: tensor(0.4709, dtype=torch.float64)
# f_score_val: tensor([0.9232, 0.0741, 0.0437, 0.8427], dtype=torch.float64)
#
# 0.00028016038933082593
#
# Validando Epoch 15
# loss_val: tensor(2.1660)
# Acc_val: tensor(0.8646, dtype=torch.float64)
# f_score_val: tensor(0.4808, dtype=torch.float64)
# f_score_val: tensor([0.9221, 0.1052, 0.0601, 0.8357], dtype=torch.float64)
#
# 0.0002988377486195477
#
# Validando Epoch 16
# loss_val: tensor(2.1466)
# Acc_val: tensor(0.8557, dtype=torch.float64)
# f_score_val: tensor(0.4801, dtype=torch.float64)
# f_score_val: tensor([0.9154, 0.1081, 0.0574, 0.8395], dtype=torch.float64)
#
# 0.0003175151079082694
#
# Validando Epoch 17
# loss_val: tensor(2.1105)
# Acc_val: tensor(0.8595, dtype=torch.float64)
# f_score_val: tensor(0.4816, dtype=torch.float64)
# f_score_val: tensor([0.9198, 0.0924, 0.0792, 0.8349], dtype=torch.float64)
#
# 0.0003361924671969912
#
# Validando Epoch 18
# loss_val: tensor(2.1090)
# Acc_val: tensor(0.8567, dtype=torch.float64)
# f_score_val: tensor(0.4828, dtype=torch.float64)
# f_score_val: tensor([0.9180, 0.1051, 0.0765, 0.8316], dtype=torch.float64)
#
# 0.0003548698264857129
#
# Validando Epoch 19
# loss_val: tensor(2.1355)
# Acc_val: tensor(0.8576, dtype=torch.float64)
# f_score_val: tensor(0.4856, dtype=torch.float64)
# f_score_val: tensor([0.9183, 0.0874, 0.0995, 0.8373], dtype=torch.float64)
#
# 0.0003735471857744346
#
# Validando Epoch 20
# loss_val: tensor(2.1238)
# Acc_val: tensor(0.8576, dtype=torch.float64)
# f_score_val: tensor(0.4970, dtype=torch.float64)
# f_score_val: tensor([0.9167, 0.1298, 0.1011, 0.8406], dtype=torch.float64)
#
# 0.00039222454506315633
#
# Validando Epoch 21
# loss_val: tensor(2.1238)
# Acc_val: tensor(0.8600, dtype=torch.float64)
# f_score_val: tensor(0.4926, dtype=torch.float64)
# f_score_val: tensor([0.9187, 0.1122, 0.1011, 0.8383], dtype=torch.float64)
#
# 0.0004109019043518781
#
# Validando Epoch 22
# loss_val: tensor(2.0997)
# Acc_val: tensor(0.8576, dtype=torch.float64)
# f_score_val: tensor(0.4841, dtype=torch.float64)
# f_score_val: tensor([0.9166, 0.1107, 0.0732, 0.8359], dtype=torch.float64)
#
# 0.00042957926364059983
#
# Validando Epoch 23
# loss_val: tensor(2.0951)
# Acc_val: tensor(0.8557, dtype=torch.float64)
# f_score_val: tensor(0.4859, dtype=torch.float64)
# f_score_val: tensor([0.9167, 0.1175, 0.0769, 0.8324], dtype=torch.float64)
#
# 0.00044825662292932153
#
# Validando Epoch 24
# loss_val: tensor(2.0989)
# Acc_val: tensor(0.8501, dtype=torch.float64)
# f_score_val: tensor(0.4970, dtype=torch.float64)
# f_score_val: tensor([0.9128, 0.1380, 0.1005, 0.8367], dtype=torch.float64)
#
# 0.0004669339822180432
#
# Validando Epoch 25
# loss_val: tensor(2.0608)
# Acc_val: tensor(0.8539, dtype=torch.float64)
# f_score_val: tensor(0.4924, dtype=torch.float64)
# f_score_val: tensor([0.9146, 0.1319, 0.0874, 0.8357], dtype=torch.float64)
#
# 0.00048561134150676503
#
# Validando Epoch 26
# loss_val: tensor(2.0516)
# Acc_val: tensor(0.8553, dtype=torch.float64)
# f_score_val: tensor(0.4941, dtype=torch.float64)
# f_score_val: tensor([0.9156, 0.1038, 0.1257, 0.8311], dtype=torch.float64)
#
# 0.0005042887007954867
#
# Validando Epoch 27
# loss_val: tensor(2.1349)
# Acc_val: tensor(0.8562, dtype=torch.float64)
# f_score_val: tensor(0.4871, dtype=torch.float64)
# f_score_val: tensor([0.9154, 0.0995, 0.1011, 0.8322], dtype=torch.float64)
#
# 0.0005040978317664867
#
# Validando Epoch 28
# loss_val: tensor(2.0492)
# Acc_val: tensor(0.8581, dtype=torch.float64)
# f_score_val: tensor(0.4934, dtype=torch.float64)
# f_score_val: tensor([0.9165, 0.1241, 0.0847, 0.8483], dtype=torch.float64)
#
# 0.0004953302441307022
#
# Validando Epoch 29
# loss_val: tensor(2.0507)
# Acc_val: tensor(0.8543, dtype=torch.float64)
# f_score_val: tensor(0.4912, dtype=torch.float64)
# f_score_val: tensor([0.9142, 0.1183, 0.0902, 0.8422], dtype=torch.float64)
#
# 0.00048700477313769213
#
# Validando Epoch 30
# loss_val: tensor(2.0911)
# Acc_val: tensor(0.8600, dtype=torch.float64)
# f_score_val: tensor(0.4982, dtype=torch.float64)
# f_score_val: tensor([0.9196, 0.1205, 0.1148, 0.8379], dtype=torch.float64)
#
# 0.000479085468560702
#
# Validando Epoch 31
# loss_val: tensor(2.0526)
# Acc_val: tensor(0.8576, dtype=torch.float64)
# f_score_val: tensor(0.5019, dtype=torch.float64)
# f_score_val: tensor([0.9163, 0.1372, 0.1148, 0.8395], dtype=torch.float64)
#
# 0.00047154034397145066
#
# Validando Epoch 32
# loss_val: tensor(2.0416)
# Acc_val: tensor(0.8511, dtype=torch.float64)
# f_score_val: tensor(0.4975, dtype=torch.float64)
# f_score_val: tensor([0.9107, 0.1471, 0.0979, 0.8342], dtype=torch.float64)
#
# 0.00046434083197082615
#
# Validando Epoch 33
# loss_val: tensor(2.0404)
# Acc_val: tensor(0.8581, dtype=torch.float64)
# f_score_val: tensor(0.5102, dtype=torch.float64)
# f_score_val: tensor([0.9149, 0.1443, 0.1339, 0.8480], dtype=torch.float64)
#
# 0.00045746132821985287
#
# Validando Epoch 34
# loss_val: tensor(2.0404)
# Acc_val: tensor(0.8581, dtype=torch.float64)
# f_score_val: tensor(0.4993, dtype=torch.float64)
# f_score_val: tensor([0.9176, 0.1230, 0.1230, 0.8338], dtype=torch.float64)
#
# 0.00045087880765604685
# Validando Epoch 35
# loss_val: tensor(2.0457)
# Acc_val: tensor(0.8590, dtype=torch.float64)
# f_score_val: tensor(0.4983, dtype=torch.float64)
# f_score_val: tensor([0.9164, 0.1438, 0.0916, 0.8414], dtype=torch.float64)
#
# 0.00044457249976699993
#
# Validando Epoch 36
# loss_val: tensor(2.0408)
# Acc_val: tensor(0.8600, dtype=torch.float64)
# f_score_val: tensor(0.4970, dtype=torch.float64)
# f_score_val: tensor([0.9187, 0.1293, 0.1005, 0.8394], dtype=torch.float64)
#
# 0.0004385236124730358
#
# Validando Epoch 37
# loss_val: tensor(2.0641)
# Acc_val: tensor(0.8548, dtype=torch.float64)
# f_score_val: tensor(0.4986, dtype=torch.float64)
# f_score_val: tensor([0.9150, 0.1387, 0.1022, 0.8386], dtype=torch.float64)
#
# 0.00043271509624714986
#
# Validando Epoch 38
# loss_val: tensor(2.0651)
# Acc_val: tensor(0.8604, dtype=torch.float64)
# f_score_val: tensor(0.4977, dtype=torch.float64)
# f_score_val: tensor([0.9186, 0.1139, 0.1169, 0.8411], dtype=torch.float64)
#
# 0.00042713144172121335
#
# Validando Epoch 39
# loss_val: tensor(2.0658)
# Acc_val: tensor(0.8557, dtype=torch.float64)
# f_score_val: tensor(0.4933, dtype=torch.float64)
# f_score_val: tensor([0.9150, 0.1235, 0.0989, 0.8357], dtype=torch.float64)
#
# 0.0004217585053015187
#
# Validando Epoch 40
# loss_val: tensor(2.0380)
# Acc_val: tensor(0.8618, dtype=torch.float64)
# f_score_val: tensor(0.5010, dtype=torch.float64)
# f_score_val: tensor([0.9194, 0.1277, 0.1213, 0.8355], dtype=torch.float64)
#
# 0.00041658335832500285
#
# Validando Epoch 41
# loss_val: tensor(2.0504)
# Acc_val: tensor(0.8567, dtype=torch.float64)
# f_score_val: tensor(0.5091, dtype=torch.float64)
# f_score_val: tensor([0.9170, 0.1626, 0.1213, 0.8354], dtype=torch.float64)
#
# 0.00041159415609041646
#
# Validando Epoch 42
# loss_val: tensor(2.0563)
# Acc_val: tensor(0.8618, dtype=torch.float64)
# f_score_val: tensor(0.5031, dtype=torch.float64)
# f_score_val: tensor([0.9202, 0.1443, 0.1038, 0.8440], dtype=torch.float64)
#
# 0.00040678002374195825
#
# Validando Epoch 43
# loss_val: tensor(2.0499)
# Acc_val: tensor(0.8600, dtype=torch.float64)
# f_score_val: tensor(0.5141, dtype=torch.float64)
# f_score_val: tensor([0.9180, 0.1634, 0.1366, 0.8385], dtype=torch.float64)
#
# 0.0004021309565011369
#
# Validando Epoch 44
# loss_val: tensor(2.0560)
# Acc_val: tensor(0.8623, dtype=torch.float64)
# f_score_val: tensor(0.5025, dtype=torch.float64)
# f_score_val: tensor([0.9193, 0.1164, 0.1240, 0.8501], dtype=torch.float64)
#
# 0.00039763773216240845
#
# Validando Epoch 45
# loss_val: tensor(2.0557)
# Acc_val: tensor(0.8609, dtype=torch.float64)
# f_score_val: tensor(0.5040, dtype=torch.float64)
# f_score_val: tensor([0.9190, 0.1181, 0.1366, 0.8424], dtype=torch.float64)
#
# 0.00039329183410991405
#
# Validando Epoch 46
# loss_val: tensor(2.0964)
# Acc_val: tensor(0.8623, dtype=torch.float64)
# f_score_val: tensor(0.4953, dtype=torch.float64)
# f_score_val: tensor([0.9186, 0.0990, 0.1230, 0.8405], dtype=torch.float64)
#
# 0.000389085383392267
#
# Validando Epoch 47
# loss_val: tensor(2.1163)
# Acc_val: tensor(0.8623, dtype=torch.float64)
# f_score_val: tensor(0.4911, dtype=torch.float64)
# f_score_val: tensor([0.9196, 0.0923, 0.1077, 0.8447], dtype=torch.float64)
#
# 0.0003850110786221733
#
# Validando Epoch 48
# loss_val: tensor(2.1050)
# Acc_val: tensor(0.8689, dtype=torch.float64)
# f_score_val: tensor(0.4940, dtype=torch.float64)
# f_score_val: tensor([0.9240, 0.0967, 0.1131, 0.8421], dtype=torch.float64)
#
# 0.00038106214265742845
#
# Validando Epoch 49
# loss_val: tensor(2.1159)
# Acc_val: tensor(0.8642, dtype=torch.float64)
# f_score_val: tensor(0.4859, dtype=torch.float64)
# f_score_val: tensor([0.9215, 0.0891, 0.0907, 0.8423], dtype=torch.float64)

# %%
plt.plot(hist_train_loss, label='loss train')
plt.plot(hist_val_loss,label='loss val')
plt.legend(loc='upper left')
plt.title("Loss vs epoch")
plt.show()

plt.plot(hist_train_acc, label='Acc train')
plt.plot(hist_val_acc, label='Acc val')
plt.legend(loc='upper left')
plt.title("Accuracy vs epoch")
plt.show()

plt.plot(hist_train_fma, label='f_ma train')
plt.plot(hist_val_fma, label='f_ma val')
plt.legend(loc='upper left')
plt.title("F-score macro vs epoch")
plt.show()

# %%
model.eval()
print ("Validando")
loss_val, acc_val,fma_val, f_val_none, cm_val = run_epoch(data_gen(35, 'Val', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
print ("Validando Epoch",epoch)
print ("loss_val:",loss_val)
print ("Acc_val:",acc_val)
print ("f_score_val:",fma_val)
print ("f_score_val:",f_val_none)
# Out:
# Validando
# Validando Epoch 49
# loss_val: tensor(2.0925)
# Acc_val: tensor(0.8642, dtype=torch.float64)
# f_score_val: tensor(0.4949, dtype=torch.float64)
# f_score_val: tensor([0.9209, 0.1153, 0.1022, 0.8413], dtype=torch.float64)

# %%
model.eval()
print ("Testing")
predicciones = run_epoch(data_gen(35, 'Test', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
predicciones=np.concatenate(predicciones, axis=-1)
print (predicciones.shape)
print (Counter(predicciones))
sns.countplot(predicciones)
# Out:
# Testing
# SE TUVIERON QUE REPETIR 12 EJEMPLOS
# (2135,)
# Counter({0: 1570, 3: 363, 1: 131, 2: 71})

# %%
predicciones[:4]
# Out:
# array([0, 0, 1, 0])

# %% [markdown]
# np.save("predicciones_5000_50_128_d4.npy",predicciones)

# %% [markdown]
# ## Tha same, factor 2

# %%
V = 4
pesos = torch.from_numpy(class_weights).float()
print (pesos)
criterion = FocalLoss(weights=pesos)
model = make_model_concat(4, N=2,d_model=768, d_ff=128, h=4, dropout=0.4)
model_opt = NoamOpt(model.src_embed[0].d_model, 2, 5000, torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-5))

hist_train_loss=[]
hist_train_acc=[]
hist_train_fma=[]
hist_val_loss=[]
hist_val_acc=[]
hist_val_fma=[]

for epoch in range(65):
    print ("")
    print (model_opt._rate)
    print ("")
    model.train()
    DATA=data_gen(35, 'Train', 4, new_matrix)
    loss_train, acc_train,fma_train, f_none, cm_train=run_epoch(DATA, model, SimpleLossComputeFL(criterion, model_opt), 'Train')
    hist_train_loss.append(loss_train)
    hist_train_acc.append(acc_train)
    hist_train_fma.append(fma_train)

    model.eval()
    loss_val, acc_val,fma_val, f_val_none, cm_val=run_epoch(data_gen(35, 'Val', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
    print ("Validando Epoch",epoch)
    print ("loss_val:",loss_val)
    print ("Acc_val:",acc_val)
    print ("f_score_val:",fma_val)
    print ("f_score_val:",f_val_none)
    hist_val_loss.append(loss_val)
    hist_val_acc.append(acc_val)
    hist_val_fma.append(fma_val)
# Out:
# tensor([ 0.4353, 28.9727, 20.9671,  0.6172])
# Creando modelo con salida Softmax
#
# 0
#
# Validando Epoch 0
# loss_val: tensor(2.2115)
# Acc_val: tensor(0.3405, dtype=torch.float64)
# f_score_val: tensor(0.1834, dtype=torch.float64)
# f_score_val: tensor([0.5798, 0.0525, 0.0500, 0.0513], dtype=torch.float64)
#
# 3.735471857744346e-05
#
# Validando Epoch 1
# loss_val: tensor(2.1832)
# Acc_val: tensor(0.3785, dtype=torch.float64)
# f_score_val: tensor(0.1993, dtype=torch.float64)
# f_score_val: tensor([0.6253, 0.0590, 0.0534, 0.0595], dtype=torch.float64)
#
# 7.470943715488692e-05
#
# Validando Epoch 2
# loss_val: tensor(2.1493)
# Acc_val: tensor(0.4529, dtype=torch.float64)
# f_score_val: tensor(0.2307, dtype=torch.float64)
# f_score_val: tensor([0.7061, 0.0641, 0.0504, 0.1022], dtype=torch.float64)
#
# 0.00011206415573233038
#
# Validando Epoch 3
# loss_val: tensor(2.1520)
# Acc_val: tensor(0.5719, dtype=torch.float64)
# f_score_val: tensor(0.2921, dtype=torch.float64)
# f_score_val: tensor([0.7898, 0.0616, 0.0487, 0.2682], dtype=torch.float64)
#
# 0.00014941887430977384
#
# Validando Epoch 4
# loss_val: tensor(2.1755)
# Acc_val: tensor(0.7152, dtype=torch.float64)
# f_score_val: tensor(0.4016, dtype=torch.float64)
# f_score_val: tensor([0.8475, 0.0673, 0.0550, 0.6368], dtype=torch.float64)
#
# 0.0001867735928872173
#
# Validando Epoch 5
# loss_val: tensor(2.1367)
# Acc_val: tensor(0.7653, dtype=torch.float64)
# f_score_val: tensor(0.4342, dtype=torch.float64)
# f_score_val: tensor([0.8749, 0.0785, 0.0563, 0.7272], dtype=torch.float64)
#
# 0.00022412831146466076
#
# Validando Epoch 6
# loss_val: tensor(2.1536)
# Acc_val: tensor(0.8009, dtype=torch.float64)
# f_score_val: tensor(0.4531, dtype=torch.float64)
# f_score_val: tensor([0.9001, 0.0825, 0.0803, 0.7493], dtype=torch.float64)
#
# 0.00026148303004210424
#
# Validando Epoch 7
# loss_val: tensor(2.1307)
# Acc_val: tensor(0.8089, dtype=torch.float64)
# f_score_val: tensor(0.4594, dtype=torch.float64)
# f_score_val: tensor([0.9048, 0.0785, 0.0941, 0.7601], dtype=torch.float64)
#
# 0.0002988377486195477
#
# Validando Epoch 8
# loss_val: tensor(2.1721)
# Acc_val: tensor(0.8365, dtype=torch.float64)
# f_score_val: tensor(0.4555, dtype=torch.float64)
# f_score_val: tensor([0.9213, 0.0541, 0.0648, 0.7819], dtype=torch.float64)
#
# 0.0003361924671969912
#
# Validando Epoch 9
# loss_val: tensor(2.1560)
# Acc_val: tensor(0.8454, dtype=torch.float64)
# f_score_val: tensor(0.4771, dtype=torch.float64)
# f_score_val: tensor([0.9180, 0.0593, 0.1197, 0.8113], dtype=torch.float64)
#
# 0.0003735471857744346
#
# Validando Epoch 10
# loss_val: tensor(2.1475)
# Acc_val: tensor(0.8548, dtype=torch.float64)
# f_score_val: tensor(0.4818, dtype=torch.float64)
# f_score_val: tensor([0.9261, 0.0861, 0.1055, 0.8095], dtype=torch.float64)
#
# 0.0004109019043518781
#
# Validando Epoch 11
# loss_val: tensor(2.1004)
# Acc_val: tensor(0.8506, dtype=torch.float64)
# f_score_val: tensor(0.4840, dtype=torch.float64)
# f_score_val: tensor([0.9219, 0.0820, 0.1197, 0.8124], dtype=torch.float64)
#
# 0.00044825662292932153
#
# Validando Epoch 12
# loss_val: tensor(2.1539)
# Acc_val: tensor(0.8562, dtype=torch.float64)
# f_score_val: tensor(0.4859, dtype=torch.float64)
# f_score_val: tensor([0.9253, 0.0798, 0.1093, 0.8292], dtype=torch.float64)
#
# 0.00048561134150676503
#
# Validando Epoch 13
# loss_val: tensor(2.1202)
# Acc_val: tensor(0.8571, dtype=torch.float64)
# f_score_val: tensor(0.4906, dtype=torch.float64)
# f_score_val: tensor([0.9248, 0.1066, 0.1087, 0.8221], dtype=torch.float64)
#
# 0.0005229660600842085
#
# Validando Epoch 14
# loss_val: tensor(2.1201)
# Acc_val: tensor(0.8571, dtype=torch.float64)
# f_score_val: tensor(0.4837, dtype=torch.float64)
# f_score_val: tensor([0.9245, 0.0836, 0.1046, 0.8219], dtype=torch.float64)
#
# 0.0005603207786616519
#
# Validando Epoch 15
# loss_val: tensor(2.1064)
# Acc_val: tensor(0.8482, dtype=torch.float64)
# f_score_val: tensor(0.4969, dtype=torch.float64)
# f_score_val: tensor([0.9172, 0.1344, 0.1126, 0.8234], dtype=torch.float64)
#
# 0.0005976754972390954
#
# Validando Epoch 16
# loss_val: tensor(2.0519)
# Acc_val: tensor(0.8398, dtype=torch.float64)
# f_score_val: tensor(0.4930, dtype=torch.float64)
# f_score_val: tensor([0.9128, 0.1130, 0.1262, 0.8201], dtype=torch.float64)
#
# 0.0006350302158165388
#
# Validando Epoch 17
# loss_val: tensor(2.0648)
# Acc_val: tensor(0.8478, dtype=torch.float64)
# f_score_val: tensor(0.4940, dtype=torch.float64)
# f_score_val: tensor([0.9166, 0.1383, 0.0998, 0.8215], dtype=torch.float64)
#
# 0.0006723849343939824
#
# Validando Epoch 18
# loss_val: tensor(2.0513)
# Acc_val: tensor(0.8379, dtype=torch.float64)
# f_score_val: tensor(0.4815, dtype=torch.float64)
# f_score_val: tensor([0.9099, 0.1090, 0.0817, 0.8256], dtype=torch.float64)
#
# 0.0007097396529714258
#
# Validando Epoch 19
# loss_val: tensor(2.0920)
# Acc_val: tensor(0.8337, dtype=torch.float64)
# f_score_val: tensor(0.4839, dtype=torch.float64)
# f_score_val: tensor([0.9069, 0.1098, 0.0902, 0.8287], dtype=torch.float64)
#
# 0.0007470943715488692
#
# Validando Epoch 20
# loss_val: tensor(2.0478)
# Acc_val: tensor(0.8525, dtype=torch.float64)
# f_score_val: tensor(0.4976, dtype=torch.float64)
# f_score_val: tensor([0.9149, 0.1236, 0.1052, 0.8466], dtype=torch.float64)
#
# 0.0007844490901263127
#
# Validando Epoch 21
# loss_val: tensor(2.0673)
# Acc_val: tensor(0.8347, dtype=torch.float64)
# f_score_val: tensor(0.4908, dtype=torch.float64)
# f_score_val: tensor([0.9070, 0.1271, 0.1060, 0.8231], dtype=torch.float64)
#
# 0.0008218038087037562
#
# Validando Epoch 22
# loss_val: tensor(2.0468)
# Acc_val: tensor(0.8473, dtype=torch.float64)
# f_score_val: tensor(0.4893, dtype=torch.float64)
# f_score_val: tensor([0.9140, 0.1103, 0.1060, 0.8271], dtype=torch.float64)
#
# 0.0008591585272811997
#
# Validando Epoch 23
# loss_val: tensor(2.0896)
# Acc_val: tensor(0.8632, dtype=torch.float64)
# f_score_val: tensor(0.4982, dtype=torch.float64)
# f_score_val: tensor([0.9225, 0.1158, 0.1142, 0.8403], dtype=torch.float64)
#
# 0.0008965132458586431
#
# Validando Epoch 24
# loss_val: tensor(2.0650)
# Acc_val: tensor(0.8529, dtype=torch.float64)
# f_score_val: tensor(0.4923, dtype=torch.float64)
# f_score_val: tensor([0.9139, 0.1217, 0.1027, 0.8310], dtype=torch.float64)
#
# 0.0009338679644360864
#
# Validando Epoch 25
# loss_val: tensor(2.0778)
# Acc_val: tensor(0.8534, dtype=torch.float64)
# f_score_val: tensor(0.4930, dtype=torch.float64)
# f_score_val: tensor([0.9152, 0.1077, 0.1120, 0.8370], dtype=torch.float64)
#
# 0.0009712226830135301
#
# Validando Epoch 26
# loss_val: tensor(2.0698)
# Acc_val: tensor(0.8590, dtype=torch.float64)
# f_score_val: tensor(0.4949, dtype=torch.float64)
# f_score_val: tensor([0.9184, 0.1130, 0.1120, 0.8361], dtype=torch.float64)
#
# 0.0010085774015909735
#
# Validando Epoch 27
# loss_val: tensor(2.0545)
# Acc_val: tensor(0.8539, dtype=torch.float64)
# f_score_val: tensor(0.4989, dtype=torch.float64)
# f_score_val: tensor([0.9148, 0.1251, 0.1120, 0.8437], dtype=torch.float64)
#
# 0.0010081956635329735
#
# Validando Epoch 28
# loss_val: tensor(2.0560)
# Acc_val: tensor(0.8515, dtype=torch.float64)
# f_score_val: tensor(0.4894, dtype=torch.float64)
# f_score_val: tensor([0.9135, 0.1118, 0.0941, 0.8384], dtype=torch.float64)
#
# 0.0009906604882614044
#
# Validando Epoch 29
# loss_val: tensor(2.0800)
# Acc_val: tensor(0.8646, dtype=torch.float64)
# f_score_val: tensor(0.4926, dtype=torch.float64)
# f_score_val: tensor([0.9225, 0.1197, 0.0852, 0.8431], dtype=torch.float64)
#
# 0.0009740095462753843
#
# Validando Epoch 30
# loss_val: tensor(2.0893)
# Acc_val: tensor(0.8576, dtype=torch.float64)
# f_score_val: tensor(0.4933, dtype=torch.float64)
# f_score_val: tensor([0.9186, 0.1203, 0.0940, 0.8406], dtype=torch.float64)
#
# 0.000958170937121404
#
# Validando Epoch 31
# loss_val: tensor(2.0550)
# Acc_val: tensor(0.8534, dtype=torch.float64)
# f_score_val: tensor(0.4994, dtype=torch.float64)
# f_score_val: tensor([0.9145, 0.1230, 0.1158, 0.8442], dtype=torch.float64)
#
# 0.0009430806879429013
#
# Validando Epoch 32
# loss_val: tensor(2.0805)
# Acc_val: tensor(0.8595, dtype=torch.float64)
# f_score_val: tensor(0.4970, dtype=torch.float64)
# f_score_val: tensor([0.9209, 0.1208, 0.1158, 0.8305], dtype=torch.float64)
#
# 0.0009286816639416523
#
# Validando Epoch 33
# loss_val: tensor(2.0549)
# Acc_val: tensor(0.8656, dtype=torch.float64)
# f_score_val: tensor(0.5030, dtype=torch.float64)
# f_score_val: tensor([0.9231, 0.1318, 0.1158, 0.8414], dtype=torch.float64)
#
# 0.0009149226564397057
#
# Validando Epoch 34
# loss_val: tensor(2.0732)
# Acc_val: tensor(0.8585, dtype=torch.float64)
# f_score_val: tensor(0.4989, dtype=torch.float64)
# f_score_val: tensor([0.9176, 0.1483, 0.0891, 0.8405], dtype=torch.float64)
#
# 0.0009017576153120937
# Validando Epoch 35
# loss_val: tensor(2.0915)
# Acc_val: tensor(0.8679, dtype=torch.float64)
# f_score_val: tensor(0.4997, dtype=torch.float64)
# f_score_val: tensor([0.9247, 0.1301, 0.1005, 0.8434], dtype=torch.float64)
#
# 0.0008891449995339999
#
# Validando Epoch 36
# loss_val: tensor(2.1020)
# Acc_val: tensor(0.8674, dtype=torch.float64)
# f_score_val: tensor(0.5004, dtype=torch.float64)
# f_score_val: tensor([0.9239, 0.1290, 0.0995, 0.8494], dtype=torch.float64)
#
# 0.0008770472249460716
#
# Validando Epoch 37
# loss_val: tensor(2.0639)
# Acc_val: tensor(0.8571, dtype=torch.float64)
# f_score_val: tensor(0.4982, dtype=torch.float64)
# f_score_val: tensor([0.9161, 0.1359, 0.0951, 0.8458], dtype=torch.float64)
#
# 0.0008654301924942997
#
# Validando Epoch 38
# loss_val: tensor(2.1036)
# Acc_val: tensor(0.8660, dtype=torch.float64)
# f_score_val: tensor(0.5006, dtype=torch.float64)
# f_score_val: tensor([0.9227, 0.1270, 0.1087, 0.8438], dtype=torch.float64)
#
# 0.0008542628834424267
#
# Validando Epoch 39
# loss_val: tensor(2.0655)
# Acc_val: tensor(0.8689, dtype=torch.float64)
# f_score_val: tensor(0.5075, dtype=torch.float64)
# f_score_val: tensor([0.9264, 0.1475, 0.1131, 0.8429], dtype=torch.float64)
#
# 0.0008435170106030374
#
# Validando Epoch 40
# loss_val: tensor(2.0909)
# Acc_val: tensor(0.8689, dtype=torch.float64)
# f_score_val: tensor(0.4974, dtype=torch.float64)
# f_score_val: tensor([0.9262, 0.1126, 0.1087, 0.8422], dtype=torch.float64)
#
# 0.0008331667166500057
#
# Validando Epoch 41
# loss_val: tensor(2.0829)
# Acc_val: tensor(0.8632, dtype=torch.float64)
# f_score_val: tensor(0.4966, dtype=torch.float64)
# f_score_val: tensor([0.9220, 0.1251, 0.1038, 0.8353], dtype=torch.float64)
#
# 0.0008231883121808329
#
# Validando Epoch 42
# loss_val: tensor(2.0517)
# Acc_val: tensor(0.8689, dtype=torch.float64)
# f_score_val: tensor(0.5046, dtype=torch.float64)
# f_score_val: tensor([0.9255, 0.1379, 0.1104, 0.8447], dtype=torch.float64)
#
# 0.0008135600474839165
#
# Validando Epoch 43
# loss_val: tensor(2.0606)
# Acc_val: tensor(0.8703, dtype=torch.float64)
# f_score_val: tensor(0.4954, dtype=torch.float64)
# f_score_val: tensor([0.9256, 0.1344, 0.0863, 0.8352], dtype=torch.float64)
#
# 0.0008042619130022738
#
# Validando Epoch 44
# loss_val: tensor(2.0539)
# Acc_val: tensor(0.8562, dtype=torch.float64)
# f_score_val: tensor(0.4951, dtype=torch.float64)
# f_score_val: tensor([0.9158, 0.1279, 0.1033, 0.8336], dtype=torch.float64)
#
# 0.0007952754643248169
#
# Validando Epoch 45
# loss_val: tensor(2.0533)
# Acc_val: tensor(0.8609, dtype=torch.float64)
# f_score_val: tensor(0.4991, dtype=torch.float64)
# f_score_val: tensor([0.9190, 0.1074, 0.1230, 0.8470], dtype=torch.float64)
#
# 0.0007865836682198281
#
# Validando Epoch 46
# loss_val: tensor(2.0652)
# Acc_val: tensor(0.8660, dtype=torch.float64)
# f_score_val: tensor(0.5013, dtype=torch.float64)
# f_score_val: tensor([0.9246, 0.1330, 0.1033, 0.8443], dtype=torch.float64)
#
# 0.000778170766784534
#
# Validando Epoch 47
# loss_val: tensor(2.0888)
# Acc_val: tensor(0.8707, dtype=torch.float64)
# f_score_val: tensor(0.4996, dtype=torch.float64)
# f_score_val: tensor([0.9258, 0.1227, 0.1033, 0.8466], dtype=torch.float64)
#
# 0.0007700221572443466
#
# Validando Epoch 48
# loss_val: tensor(2.0670)
# Acc_val: tensor(0.8707, dtype=torch.float64)
# f_score_val: tensor(0.4995, dtype=torch.float64)
# f_score_val: tensor([0.9255, 0.1366, 0.0889, 0.8469], dtype=torch.float64)
#
# 0.0007621242853148569
#
# Validando Epoch 49
# loss_val: tensor(2.1039)
# Acc_val: tensor(0.8614, dtype=torch.float64)
# f_score_val: tensor(0.5009, dtype=torch.float64)
# f_score_val: tensor([0.9191, 0.1254, 0.1142, 0.8447], dtype=torch.float64)
#
# 0.000754464550354321
#
# Validando Epoch 50
# loss_val: tensor(2.0794)
# Acc_val: tensor(0.8637, dtype=torch.float64)
# f_score_val: tensor(0.5055, dtype=torch.float64)
# f_score_val: tensor([0.9225, 0.1530, 0.1077, 0.8389], dtype=torch.float64)
#
# 0.0007470312207963323
#
# Validando Epoch 51
# loss_val: tensor(2.0518)
# Acc_val: tensor(0.8707, dtype=torch.float64)
# f_score_val: tensor(0.5025, dtype=torch.float64)
# f_score_val: tensor([0.9258, 0.1315, 0.1066, 0.8462], dtype=torch.float64)
#
# 0.0007398133585712865
#
# Validando Epoch 52
# loss_val: tensor(2.0529)
# Acc_val: tensor(0.8712, dtype=torch.float64)
# f_score_val: tensor(0.4979, dtype=torch.float64)
# f_score_val: tensor([0.9260, 0.1136, 0.1126, 0.8396], dtype=torch.float64)
#
# 0.0007328007514088822
#
# Validando Epoch 53
# loss_val: tensor(2.0740)
# Acc_val: tensor(0.8689, dtype=torch.float64)
# f_score_val: tensor(0.5076, dtype=torch.float64)
# f_score_val: tensor([0.9236, 0.1410, 0.1197, 0.8463], dtype=torch.float64)
#
# 0.0007259838520684954
#
# Validando Epoch 54
# loss_val: tensor(2.0756)
# Acc_val: tensor(0.8660, dtype=torch.float64)
# f_score_val: tensor(0.5112, dtype=torch.float64)
# f_score_val: tensor([0.9237, 0.1678, 0.1120, 0.8411], dtype=torch.float64)
#
# 0.0007193537236748424
#
# Validando Epoch 55
# loss_val: tensor(2.0727)
# Acc_val: tensor(0.8712, dtype=torch.float64)
# f_score_val: tensor(0.5012, dtype=torch.float64)
# f_score_val: tensor([0.9255, 0.1224, 0.1120, 0.8447], dtype=torch.float64)
#
# 0.0007129019904470364
#
# Validando Epoch 56
# loss_val: tensor(2.0519)
# Acc_val: tensor(0.8684, dtype=torch.float64)
# f_score_val: tensor(0.5030, dtype=torch.float64)
# f_score_val: tensor([0.9246, 0.1426, 0.0995, 0.8452], dtype=torch.float64)
#
# 0.0007066207932032196
#
# Validando Epoch 57
# loss_val: tensor(2.0732)
# Acc_val: tensor(0.8721, dtype=torch.float64)
# f_score_val: tensor(0.4980, dtype=torch.float64)
# f_score_val: tensor([0.9264, 0.1181, 0.1027, 0.8449], dtype=torch.float64)
#
# 0.0007005027491032151
#
# Validando Epoch 58
# loss_val: tensor(2.0531)
# Acc_val: tensor(0.8679, dtype=torch.float64)
# f_score_val: tensor(0.5048, dtype=torch.float64)
# f_score_val: tensor([0.9225, 0.1249, 0.1240, 0.8479], dtype=torch.float64)
#
# 0.0006945409151602594
#
# Validando Epoch 59
# loss_val: tensor(2.0690)
# Acc_val: tensor(0.8660, dtype=torch.float64)
# f_score_val: tensor(0.5039, dtype=torch.float64)
# f_score_val: tensor([0.9230, 0.1378, 0.1107, 0.8440], dtype=torch.float64)
#
# 0.0006887287551117565
#
# Validando Epoch 60
# loss_val: tensor(2.0512)
# Acc_val: tensor(0.8721, dtype=torch.float64)
# f_score_val: tensor(0.5112, dtype=torch.float64)
# f_score_val: tensor([0.9269, 0.1612, 0.1077, 0.8492], dtype=torch.float64)
#
# 0.0006830601092896175
#
# Validando Epoch 61
# loss_val: tensor(2.0508)
# Acc_val: tensor(0.8726, dtype=torch.float64)
# f_score_val: tensor(0.5031, dtype=torch.float64)
# f_score_val: tensor([0.9262, 0.1416, 0.1011, 0.8436], dtype=torch.float64)
#
# 0.0006775291671744138
#
# Validando Epoch 62
# loss_val: tensor(2.0978)
# Acc_val: tensor(0.8726, dtype=torch.float64)
# f_score_val: tensor(0.4954, dtype=torch.float64)
# f_score_val: tensor([0.9272, 0.1044, 0.1038, 0.8463], dtype=torch.float64)
#
# 0.0006721304423553156
#
# Validando Epoch 63
# loss_val: tensor(2.0744)
# Acc_val: tensor(0.8726, dtype=torch.float64)
# f_score_val: tensor(0.5082, dtype=torch.float64)
# f_score_val: tensor([0.9263, 0.1397, 0.1202, 0.8467], dtype=torch.float64)
#
# 0.0006668587496504999
#
# Validando Epoch 64
# loss_val: tensor(2.0509)
# Acc_val: tensor(0.8721, dtype=torch.float64)
# f_score_val: tensor(0.5050, dtype=torch.float64)
# f_score_val: tensor([0.9253, 0.1422, 0.1058, 0.8465], dtype=torch.float64)

# %%
plt.plot(hist_train_loss, label='loss train')
plt.plot(hist_val_loss,label='loss val')
plt.legend(loc='upper left')
plt.title("Loss vs epoch")
plt.show()

plt.plot(hist_train_acc, label='Acc train')
plt.plot(hist_val_acc, label='Acc val')
plt.legend(loc='upper left')
plt.title("Accuracy vs epoch")
plt.show()

plt.plot(hist_train_fma, label='f_ma train')
plt.plot(hist_val_fma, label='f_ma val')
plt.legend(loc='upper left')
plt.title("F-score macro vs epoch")
plt.show()

# %%
model.eval()
print ("Validando")
loss_val, acc_val,fma_val, f_val_none, cm_val = run_epoch(data_gen(35, 'Val', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Val')
print ("Validando Epoch",epoch)
print ("loss_val:",loss_val)
print ("Acc_val:",acc_val)
print ("f_score_val:",fma_val)
print ("f_score_val:",f_val_none)

model.eval()
print ("Testing")
predicciones = run_epoch(data_gen(35, 'Test', 4, new_matrix), model, SimpleLossComputeFL(criterion, None),'Test')
predicciones=np.concatenate(predicciones, axis=-1)
print (predicciones.shape)
print (Counter(predicciones))
sns.countplot(predicciones)
# Out:
# Validando
# Validando Epoch 64
# loss_val: tensor(2.0815)
# Acc_val: tensor(0.8731, dtype=torch.float64)
# f_score_val: tensor(0.5086, dtype=torch.float64)
# f_score_val: tensor([0.9275, 0.1397, 0.1262, 0.8409], dtype=torch.float64)
# Testing
# SE TUVIERON QUE REPETIR 12 EJEMPLOS
# (2135,)
# Counter({0: 1580, 3: 351, 1: 129, 2: 75})
