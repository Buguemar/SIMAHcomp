# %% [markdown]
# # Reporte de resultados Train/Val set
#
# ## Modelos 4 classes

# %%
#'baselines_4/cnn1_ce10_100.h5'
print ("Nh\t\t| IH\t\t| PH\t\t| SH\t\t| F-Macro")
print (0.92792793 ,'\t',0. ,'\t\t',        0.,'\t\t',         0.84057971,'\t',    0.4421269095182139)
#('baselines_4/cnn1_focal10_100.h5')
print (0.78674791,'\t', 0.13793103 ,'\t',0.09756098 ,'\t',0.56389987,'\t',   0.396534945974999  )
#('baselines_4/cnn1_100_focal20_100.h5')
print (0.90885585 ,'\t',0.08      ,'\t\t', 0.08 ,'\t\t',      0.53174603 ,'\t',0.40015047044458807)
#'baselines_4/cnn1_100_focal20_100_g2.h5'
print (0.91094148,'\t', 0.04255319,'\t', 0.07692308,'\t', 0.64953271,'\t',   0.41998761362994613)
#'baselines_4/cnn1_100_focal20_100_g3.h5
print (0.90553955 ,'\t',0.05517241,'\t', 0.07407407,'\t', 0.55874674,'\t',  0.3983831923671509)
#'baselines_4/cnn1_100_focal20_100_g4.h5
print (0.82479584 ,'\t',0.12264151 ,'\t',0.05555556 ,'\t',0.70242915,'\t', 0.4263555143500758)
#('baselines_4/rnn_simple_100_focal15.h5')
print (0.9197861  ,'\t',0.10884354 ,'\t',0.0729927  ,'\t',0.78439425,'\t',  0.47150414622873116)
#('baselines_4/rnn1_100_focal15.h5')
print (0.92418033,'\t', 0.14876033 ,'\t',0.17073171 ,'\t',0.85254692,'\t',  0.5240548206636296)
#('baselines_4/rnn2_100_focal15.h5')
print (0.9054658 ,'\t', 0.13714286 ,'\t',0.10909091 ,'\t',0.74418605,'\t',  0.47397140213787825)
#('baselines_4/rnn3_100_focal15.h5')
print (0.78454333 ,'\t',0.10327022,'\t', 0.10362694 ,'\t',0.71553611,'\t', 0.42674414932927196)
#('baselines_4/cnn1_focal10_100_g3_64.h5')
print (0.83127273,'\t', 0.12668464 ,'\t',0.07792208 ,'\t',0.44346549,'\t',0.3698362333092613)
#('baselines_4/cnn1_focal10_100_g3_100.h5')
print (0.91473851 ,'\t',0. ,'\t\t',        0.09386282 ,'\t',0.52150538,'\t',    0.38252667563241805)

#pasan a transformer: 1,2,7,8,9,10,12
# Out:
# Nh		| IH		| PH		| SH		| F-Macro
# 0.92792793 	 0.0 		 0.0 		 0.84057971 	 0.4421269095182139
# 0.78674791 	 0.13793103 	 0.09756098 	 0.56389987 	 0.396534945974999
# 0.90885585 	 0.08 		 0.08 		 0.53174603 	 0.40015047044458807
# 0.91094148 	 0.04255319 	 0.07692308 	 0.64953271 	 0.41998761362994613
# 0.90553955 	 0.05517241 	 0.07407407 	 0.55874674 	 0.3983831923671509
# 0.82479584 	 0.12264151 	 0.05555556 	 0.70242915 	 0.4263555143500758
# 0.9197861 	 0.10884354 	 0.0729927 	 0.78439425 	 0.47150414622873116
# 0.92418033 	 0.14876033 	 0.17073171 	 0.85254692 	 0.5240548206636296
# 0.9054658 	 0.13714286 	 0.10909091 	 0.74418605 	 0.47397140213787825
# 0.78454333 	 0.10327022 	 0.10362694 	 0.71553611 	 0.42674414932927196
# 0.83127273 	 0.12668464 	 0.07792208 	 0.44346549 	 0.3698362333092613
# 0.91473851 	 0.0 		 0.09386282 	 0.52150538 	 0.38252667563241805

# %% [markdown]
# ### binary + CNN1

# %% [markdown]
# ### binary + CNN2

# %% [markdown]
# ### binary + RNN1

# %% [markdown]
# ### binary + RNN2

# %% [markdown]
# ### binary + RNN3

# %% [markdown]
# ### Comité Best Fit

# %% [markdown]
# ### Comité Norm

# %% [markdown]
# ### Comité Average/Voting

# %% [markdown]
# ### Transformer CIARP

# %% [markdown]
# ### Transformer otros settings

# %%
print ("Non-H\t| Indirect H\t| Physical H\t| Sexual H\t| F-Macro\t| Accuracy\t| val loss (focal)")
#Entrenando modelo D: 0.2  h_dim: 128  batch_size: 64  fase: 500  factor: 1
#print (0.9076,'\t',0.1568,'\t',0.1284,'\t',0.8445,'\t',0.5093)
#print (0.9088,'\t',0.1969,'\t',0.1662,'\t',0.8478,'\t',0.5300,'\t\t',0.8460,'\t\t',1.9486)
#print ("--------\t\t| --------\t\t| --------\t\t| --------\t\t|--------\t\t|--------\t\t|")
#print ("----------------------------------------------------------------------------------------")
# Entrenando modelo D: 0.2  h_dim: 128  batch_size: 64  fase: 500  factor: 2
#print (0.9315,'\t', 0.1783, '\t',0.1490,'\t\t', 0.8525, '\t',0.5278)
#print (0.9326,'\t', 0.1598, '\t',0.1480,'\t\t', 0.8472,'\t', 0.5219, '\t',0.8778, '\t',2.0586)
#print ("----------------------------------------------------------------------------------------")                   
# Entrenando modelo D: 0.2  h_dim: 256  batch_size: 64  fase: 500  factor: 1
#print (0.9306,'\t', 0.2056, '\t',0.1059,'\t', 0.8545,'\t', 0.5242)
#print (0.9302,'\t', 0.1800, '\t\t',0.1217, '\t',0.8599,'\t', 0.5229,'\t', 0.8801,'\t', 2.0627)
#print ("----------------------------------------------------------------------------------------")
# Entrenando modelo D: 0.2  h_dim: 256  batch_size: 64  fase: 500  factor: 2
print (0.9331,'\t', 0.1303, '\t',0.2010, '\t\t',0.8524, '\t',0.5292)
print (0.9315,'\t', 0.1723,'\t', 0.1755, '\t',0.8436, '\t',0.5307,'\t', 0.8791,'\t',2.1080 )
print ("----------------------------------------------------------------------------------------")
# Entrenando modelo D: 0.2  h_dim: 128  batch_size: 64  fase: 3000  factor: 1
print (0.9333,'\t', 0.2145,'\t', 0.1441,'\t', 0.8513, '\t',0.5358)
print (0.9320,'\t', 0.2129, '\t',0.1368, '\t',0.8461, '\t',0.5320,'\t\t', 0.8791,'\t', 2.0191                    )
print ("----------------------------------------------------------------------------------------")
# Entrenando modelo D: 0.2  h_dim: 128  batch_size: 64  fase: 3000  factor: 2
#print (0.9252,'\t', 0.1746,'\t', 0.1137, '\t',0.8455,'\t',0.5147)
#print (0.9255,'\t', 0.1877,'\t', 0.1441, '\t',0.8524, '\t',0.5274, '\t',0.8713, '\t',2.0499)
#print ("----------------------------------------------------------------------------------------")
#DAR MAS EPOCHS  Entrenando modelo D: 0.2  h_dim: 256  batch_size: 64  fase: 3000  factor: 2
#print (0.8976,'\t', 0.2374,'\t', 0.1814, '\t',0.8463, '\t',0.5407)
#print (0.8963,'\t', 0.2363,'\t', 0.1590,'\t\t', 0.8413,'\t',0.5332, '\t',0.8369,'\t', 1.8005)
#print ("----------------------------------------------------------------------------------------")
#MORE EPOCHS  Entrenando modelo D: 0.2  h_dim: 128  batch_size: 64  fase: 5000  factor: 1                    
print (0.8992,'\t', 0.2507, '\t',0.1897, '\t',0.8458, '\t',0.5463)
print (0.8992,'\t', 0.2579,'\t', 0.1578, '\t',0.8537, '\t',0.5422, '\t',0.8355,'\t',1.7827)
print ("----------------------------------------------------------------------------------------")
# Entrenando modelo D: 0.2  h_dim: 128  batch_size: 64  fase: 5000  factor: 2
#print (0.9253,'\t', 0.2225,'\t', 0.1305, '\t',0.8477, '\t',0.5315)
#print (0.9249,'\t', 0.2170,'\t\t', 0.1608, '\t',0.8503, '\t',0.5383,'\t', 0.8672, '\t',2.0208)
#print ("----------------------------------------------------------------------------------------")
# Entrenando modelo D: 0.2  h_dim: 256  batch_size: 64  fase: 5000  factor: 3
print (0.9279,'\t', 0.2202, '\t',0.0951,'\t', 0.8519, '\t',0.5238)
print (0.9269,'\t', 0.2358, '\t',0.1029, '\t',0.8507, '\t',0.5291, '\t',0.8732, '\t',2.1171)
print ("----------------------------------------------------------------------------------------")
#CANDIDATOOOOOOOOOOOOOOOOOOOO  Entrenando modelo D: 0.2  h_dim: 128  batch_size: 128  fase: 500  factor: 1
print (0.9335,'\t', 0.1714, '\t',0.2405, '\t',0.8490, '\t\t',0.5486)
print (0.9358,'\t', 0.1580,'\t\t', 0.2356,'\t', 0.8542, '\t',0.5459, '\t',0.8810, '\t\t',2.0996                    )
print ("----------------------------------------------------------------------------------------")
#Entrenando modelo D: 0.2  h_dim: 128  batch_size: 128  fase: 500  factor: 3
#print (0.9162,'\t', 0.1784, '\t',0.2147,'\t', 0.8418,'\t', 0.5378)
#print (0.9164, '\t',0.2165,'\t', 0.2158,'\t', 0.8433, '\t',0.5480, '\t\t',0.8552,'\t',  1.9789)
#print ("----------------------------------------------------------------------------------------")
#MORE EPOCHS  Entrenando modelo D: 0.2  h_dim: 128  batch_size: 128  fase: 3000  factor: 2                    
#print (0.9161,'\t', 0.2076, '\t',0.2362,'\t', 0.8407, '\t',0.5501)
#print (0.9170,'\t', 0.1811,'\t', 0.2266, '\t',0.8455, '\t',0.5426,'\t', 0.8534, '\t',1.9440)
#print ("----------------------------------------------------------------------------------------")
#MAAAAAS EPOCHS  Entrenando modelo D: 0.2  h_dim: 128  batch_size: 128  fase: 5000  factor: 1
#print (0.9216,'\t', 0.2344, '\t',0.1566,'\t', 0.8220, '\t\t',0.5337)
#print (0.9220,'\t', 0.2051,'\t', 0.1798, '\t',0.8238, '\t',0.5327,'\t', 0.8525, '\t', 2.0460)
#print ("----------------------------------------------------------------------------------------")
# MENOR LOSS Entrenando modelo D: 0.3  h_dim: 128  batch_size: 64  fase: 3000  factor: 2
print (0.9252,'\t', 0.2513, '\t',0.1441,'\t', 0.8539,'\t', 0.5436)
print (0.9247,'\t', 0.2265, '\t',0.0908,'\t', 0.8457, '\t',0.5219, '\t', 0.8690, '\t\t', 1.9702)
print ("----------------------------------------------------------------------------------------")
#DARLE UN POCO MAS Entrenando modelo D: 0.3  h_dim: 256  batch_size: 128  fase: 500  factor: 3
print (0.9296,'\t', 0.1562, '\t',0.2497,'\t', 0.8538,'\t', 0.5473)
print (0.9295,'\t', 0.2235, '\t',0.2578, '\t',0.8454,'\t', 0.5641,'\t', 0.8755, '\t', 2.0795)
print ("----------------------------------------------------------------------------------------")
#DARLE MAS EPOCHS  Entrenando modelo D: 0.3  h_dim: 256  batch_size: 128  fase: 5000  factor: 1
#print (0.9115,'\t', 0.2408,'\t', 0.1892, '\t',0.8301, '\t',0.5429)
#print (0.9103,'\t', 0.2275,'\t', 0.1690, '\t\t',0.8265,'\t', 0.5333, '\t',0.8355,'\t', 1.9134)
# Out:
# Non-H	| Indirect H	| Physical H	| Sexual H	| F-Macro	| Accuracy	| val loss (focal)
# 0.9331 	 0.1303 	 0.201 		 0.8524 	 0.5292
# 0.9315 	 0.1723 	 0.1755 	 0.8436 	 0.5307 	 0.8791 	 2.108
# ----------------------------------------------------------------------------------------
# 0.9333 	 0.2145 	 0.1441 	 0.8513 	 0.5358
# 0.932 	 0.2129 	 0.1368 	 0.8461 	 0.532 		 0.8791 	 2.0191
# ----------------------------------------------------------------------------------------
# 0.8992 	 0.2507 	 0.1897 	 0.8458 	 0.5463
# 0.8992 	 0.2579 	 0.1578 	 0.8537 	 0.5422 	 0.8355 	 1.7827
# ----------------------------------------------------------------------------------------
# 0.9279 	 0.2202 	 0.0951 	 0.8519 	 0.5238
# 0.9269 	 0.2358 	 0.1029 	 0.8507 	 0.5291 	 0.8732 	 2.1171
# ----------------------------------------------------------------------------------------
# 0.9335 	 0.1714 	 0.2405 	 0.849 		 0.5486
# 0.9358 	 0.158 		 0.2356 	 0.8542 	 0.5459 	 0.881 		 2.0996
# ...
